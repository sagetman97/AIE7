# %% [markdown]
# <p align = "center" draggable=”false” ><img src="https://github.com/AI-Maker-Space/LLM-Dev-101/assets/37101144/d1343317-fa2f-41e1-8af1-1dbb18399719"
#      width="200px"
#      height="auto"/>
# </p>
#
# <h1 align="center" id="heading">OpenAI Agents SDK - AIM</h1>
#
# In this notebook, we'll go over some of the key features of the OpenAI Agents SDK - as explored through a notebook-ified version of their [Research Bot](https://github.com/openai/openai-agents-python/tree/main/examples/research_bot).

# %%
### You don't need to run this cell if you're running this notebook locally. 

#!pip install -qU openai-agents

# %% [markdown]
# API Key:

# %%
import os 
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# Nest Async:

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Agents
#
# As may be expected, the primary thing we'll do in the Agents SDK is construct Agents!
#
# Agents are constructed with a few basic properties:
#
# - A prompt, which OpenAI is using the language "instruction" for, that determines the behaviour or goal of the Agent
# - A model, the "brain" of the Agent
#
# They also typically include an additional property:
#
# - Tool(s) that equip the Agent with things it can use to get stuff done

# %% [markdown]
# ### Task 1: Create Planner Agent
#
# Let's start by creating our "Planner Agent" - which will come up with the initial set of search terms that should answer a query provided by the user.

# %%
from pydantic import BaseModel
from agents import Agent

PLANNER_PROMPT = (
    "You are a helpful research assistant. Given a query, come up with a set of web searches to perform" 
    "to best answer the query. Output between 5 and 20 terms to query for."
)

# %% [markdown]
# Next, we'll define the data models that our Planner Agent will use to structure its output. We'll create:
#
# 1. `WebSearchItem` - A model for individual search items, containing the search query and reasoning
# 2. `WebSearchPlan` - A container model that holds a list of search items
#
# These Pydantic models will help ensure our agent returns structured data that we can easily process.

# %%
class WebSearchItem(BaseModel):
    reason: str
    "Your reasoning for why this search is important to the query."

    query: str
    "The search term to use for the web search."

class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem]
    """A list of web searches to perform to best answer the query."""

# %% [markdown]
# Now we'll create our Planner Agent using the Agent class from the OpenAI Agents SDK. This agent will use the instructions defined in `PLANNER_PROMPT` and will output structured data in the form of our WebSearchPlan model. We're using the GPT-4o model for this agent to ensure high-quality search term generation.
#
# > NOTE: When we provide an `output_type` - the model will return a [structured response](https://platform.openai.com/docs/guides/structured-outputs?api-mode=responses).

# %%
planner_agent = Agent(
    name="PlannerAgent",
    instructions=PLANNER_PROMPT,
    model="gpt-4.1",
    output_type=WebSearchPlan,
)

# %% [markdown]
# #### ❓Question #1:
#
# Why is it important to provide a structured response template? (As in: Why are structured outputs helpful/preferred in Agentic workflows?)
#
# ##### ✅ Answer:
#
# Reliability & Consistency: Structured outputs ensure agents return predictable, validated data formats, eliminating parsing errors and ambiguity that can occur with free-form text responses.
# Interoperability: When multiple agents work together (Planner → Search → Writer), structured outputs create seamless data flow where each agent knows exactly what format to expect from the previous agent. Production Benefits: Easier debugging and error handling, Better performance (no text parsing needed), Simplified testing and API integration, Self-documenting code through schemas.

# %% [markdown]
# ### Task 2: Create Search Agent
#
# Now we'll create our Search Agent, which will be responsible for executing web searches based on the terms generated by the Planner Agent. This agent will take each search query, perform a web search using the `WebSearchTool`, and then summarize the results in a concise format.
#
# > NOTE: We are using the `WebSearchTool`, a hosted tool that can be used as part of an `OpenAIResponsesModel` as outlined in the [documentation](https://openai.github.io/openai-agents-python/tools/). This is based on the tools available through OpenAI's new [Responses API](https://openai.com/index/new-tools-for-building-agents/).
#
# The `SEARCH_PROMPT` below instructs the agent to create brief, focused summaries of search results. These summaries are designed to be 2-3 paragraphs, under 300 words, and capture only the essential information without unnecessary details. The goal is to provide the Writer Agent with clear, distilled information that can be efficiently synthesized into the final report.

# %%
SEARCH_PROMPT = (
    "You are a research assistant. Given a search term, you search the web for that term and"
    "produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300"
    "words. Capture the main points. Write succinctly, no need to have complete sentences or good"
    "grammar. This will be consumed by someone synthesizing a report, so its vital you capture the"
    "essence and ignore any fluff. Do not include any additional commentary other than the summary"
    "itself."
)

# %% [markdown]
# Now we'll create our Search Agent using the Agent class from the OpenAI Agents SDK. This agent will use the instructions defined in `SEARCH_PROMPT` and will utilize the `WebSearchTool` to perform web searches. We're configuring it with `tool_choice="required"` to ensure it always uses the search tool when processing requests.
#
# > NOTE: We can, as demonstrated, indicate how we want our model to use tools. You can read more about that at the bottom of the page [here](https://openai.github.io/openai-agents-python/agents/)

# %%
from agents import WebSearchTool
from agents.model_settings import ModelSettings

search_agent = Agent(
    name="Search agent",
    instructions=SEARCH_PROMPT,
    tools=[WebSearchTool()],
    model_settings=ModelSettings(tool_choice="required"),
)

# %% [markdown]
# #### ❓ Question #2:
#
# What other tools are supported in OpenAI's Responses API?
#
#
# ##### ✅ Answer:
#
# Core Tools: Beyond the WebSearchTool used in the notebook, OpenAI's Responses API supports several other built-in tools including FileSearchTool for document search, CodeInterpreterTool for Python code execution, and RetrievalTool for knowledge base access.
# Additional Capabilities: The API also includes DALLE Tool for image generation, Browser Tool for web navigation, and database tools for data manipulation. Developers can also create custom tools to extend agent capabilities for specific use cases.

# %% [markdown]
# ### Task 3: Create Writer Agent
#
# Finally, we'll create our Writer Agent, which will synthesize all the research findings into a comprehensive report. This agent takes the original query and the research summaries from the Search Agent, then produces a structured report with follow-up questions.
#
# The Writer Agent will:
# 1. Create an outline for the report structure
# 2. Generate a detailed markdown report (5-10 pages)
# 3. Provide follow-up questions for further research
#
# We'll define the prompt for this agent in the next cell. This prompt will instruct the Writer Agent on how to synthesize research findings into a comprehensive report with follow-up questions.

# %%
WRITER_PROMPT = (
    "You are a senior legal researcher and attorney tasked with writing a comprehensive legal memorandum. "
    "You will be provided with the original legal query and research findings from a research assistant.\n"
    "You should first create a detailed legal outline following standard memorandum format: "
    "1) Issue Statement, 2) Brief Answer, 3) Facts, 4) Discussion/Analysis, 5) Conclusion.\n"
    "The final output should be in markdown format, written in formal legal language with proper citations. "
    "Aim for 5-10 pages of content, at least 1500 words, focusing on legal precedent, statutory analysis, "
    "and practical implications for the client.\n"
    "For follow-up questions, provide exactly 5 unique legal research questions that would strengthen "
    "the analysis, such as additional case law, regulatory updates, or jurisdictional considerations."
)

# %% [markdown]
# #### 🏗️ Activity #1:
#
# This prompt is quite generic - modify this prompt to produce a report that is more personalized to either your personal preference, or more appropriate for a specific use case (eg. law domain research)

# %% [markdown]
# Now we'll create our Writer Agent using the Agent class from the OpenAI Agents SDK. This agent will synthesize all the research findings into a comprehensive report. We're configuring it with the `ReportData` output type to structure the response with a short summary, markdown report, and follow-up questions.

# %%
class ReportData(BaseModel):
    short_summary: str
    """A short 2-3 sentence summary of the findings."""

    markdown_report: str
    """The final report"""

    follow_up_questions: list[str]
    """Suggested topics to research further"""

# %% [markdown]
# Now we'll define our Writer Agent using the Agent class from the OpenAI Agents SDK. This agent will take the original query and research summaries, then synthesize them into a comprehensive report with follow-up questions. We've defined a custom output type called `ReportData` that structures the response with a short summary, markdown report, and follow-up questions.

# %%
writer_agent = Agent(
    name="WriterAgent",
    instructions=WRITER_PROMPT,
    model="o3-mini",
    output_type=ReportData,
)

# %% [markdown]
# #### ❓ Question #3:
#
# Why are we electing to use a reasoning model for writing our report?
#
# ##### ✅ Answer:
#
# We're using a reasoning model like o3-mini for the Writer Agent because it needs to do more than just string together search results - it has to actually think through the information and create a coherent narrative. These models are better at analyzing multiple sources, spotting patterns, and generating thoughtful content that flows logically from one section to the next. Plus, when you're asking for a 5-10 page report with proper structure and follow-up questions, you want something that can reason through the material rather than just regurgitate it.

# %% [markdown]
# ## Task 4: Create Utility Classes
#
# We'll define utility classes to help with displaying progress and managing the research workflow. The Printer class below will provide real-time updates on the research process.

# %% [markdown]
# The Printer class provides real-time progress updates during the research process. It uses Rich's Live display to show dynamic content with spinners for in-progress items and checkmarks for completed tasks. The class maintains a dictionary of items with their completion status and can selectively hide checkmarks for specific items. This creates a clean, interactive console experience that keeps the user informed about the current state of the research workflow.

# %%
from typing import Any

from rich.console import Console, Group
from rich.live import Live
from rich.spinner import Spinner

class Printer:
    def __init__(self, console: Console):
        self.live = Live(console=console)
        self.items: dict[str, tuple[str, bool]] = {}
        self.hide_done_ids: set[str] = set()
        self.live.start()

    def end(self) -> None:
        self.live.stop()

    def hide_done_checkmark(self, item_id: str) -> None:
        self.hide_done_ids.add(item_id)

    def update_item(
        self, item_id: str, content: str, is_done: bool = False, hide_checkmark: bool = False
    ) -> None:
        self.items[item_id] = (content, is_done)
        if hide_checkmark:
            self.hide_done_ids.add(item_id)
        self.flush()

    def mark_item_done(self, item_id: str) -> None:
        self.items[item_id] = (self.items[item_id][0], True)
        self.flush()

    def flush(self) -> None:
        renderables: list[Any] = []
        for item_id, (content, is_done) in self.items.items():
            if is_done:
                prefix = "✅ " if item_id not in self.hide_done_ids else ""
                renderables.append(prefix + content)
            else:
                renderables.append(Spinner("dots", text=content))
        self.live.update(Group(*renderables))

# %% [markdown]
# Let's create a ResearchManager class that will orchestrate the research process. This class will:
# 1. Plan searches based on the query
# 2. Perform those searches to gather information
# 3. Write a comprehensive report based on the gathered information
# 4. Display progress using our Printer class

# %%
from __future__ import annotations

import asyncio
import time

from agents import Runner, custom_span, gen_trace_id, trace

class ResearchManager:
    def __init__(self):
        self.console = Console()
        self.printer = Printer(self.console)

    async def run(self, query: str) -> None:
        trace_id = gen_trace_id()
        with trace("Research trace", trace_id=trace_id):
            self.printer.update_item(
                "trace_id",
                f"View trace: https://platform.openai.com/traces/trace?trace_id={trace_id}",
                is_done=True,
                hide_checkmark=True,
            )

            self.printer.update_item(
                "starting",
                "Starting research...",
                is_done=True,
                hide_checkmark=True,
            )
            search_plan = await self._plan_searches(query)
            search_results = await self._perform_searches(search_plan)
            report = await self._write_report(query, search_results)

            final_report = f"Report summary\n\n{report.short_summary}"
            self.printer.update_item("final_report", final_report, is_done=True)

            self.printer.end()

        print("\n\n=====REPORT=====\n\n")
        print(f"Report: {report.markdown_report}")
        print("\n\n=====FOLLOW UP QUESTIONS=====\n\n")
        unique_questions = []
        seen = set()
        
        for question in report.follow_up_questions:
            if question not in seen:
                unique_questions.append(question)
                seen.add(question)
        
        for i, question in enumerate(unique_questions, 1):
            print(f"{i}. {question}")

    async def _plan_searches(self, query: str) -> WebSearchPlan:
        self.printer.update_item("planning", "Planning searches...")
        result = await Runner.run(
            planner_agent,
            f"Query: {query}",
        )
        self.printer.update_item(
            "planning",
            f"Will perform {len(result.final_output.searches)} searches",
            is_done=True,
        )
        return result.final_output_as(WebSearchPlan)

    async def _perform_searches(self, search_plan: WebSearchPlan) -> list[str]:
        with custom_span("Search the web"):
            self.printer.update_item("searching", "Searching...")
            num_completed = 0
            max_concurrent = 5
            results = []
            
            for i in range(0, len(search_plan.searches), max_concurrent):
                batch = search_plan.searches[i:i+max_concurrent]
                tasks = [asyncio.create_task(self._search(item)) for item in batch]
                
                for task in asyncio.as_completed(tasks):
                    try:
                        result = await task
                        if result is not None:
                            results.append(result)
                    except Exception as e:
                        print(f"Search error: {e}")
                        
                    num_completed += 1
                    self.printer.update_item(
                        "searching", f"Searching... {num_completed}/{len(search_plan.searches)} completed"
                    )
            
            self.printer.mark_item_done("searching")
            return results

    async def _search(self, item: WebSearchItem) -> str | None:
        input = f"Search term: {item.query}\nReason for searching: {item.reason}"
        try:
            result = await Runner.run(
                search_agent,
                input,
            )
            return str(result.final_output)
        except Exception as e:
            print(f"Error searching for '{item.query}': {e}")
            return None

    async def _write_report(self, query: str, search_results: list[str]) -> ReportData:
        self.printer.update_item("writing", "Thinking about report...")
        input = f"Original query: {query}\nSummarized search results: {search_results}"
        
        result = Runner.run_streamed(
            writer_agent,
            input,
        )
        
        update_messages = [
            "Thinking about report...",
            "Planning report structure...",
            "Writing outline...",
            "Creating sections...",
            "Cleaning up formatting...",
            "Finalizing report...",
            "Finishing report...",
        ]

        last_update = time.time()
        next_message = 0
        
        async for event in result.stream_events():
            if time.time() - last_update > 5 and next_message < len(update_messages):
                self.printer.update_item("writing", update_messages[next_message])
                next_message += 1
                last_update = time.time()

        self.printer.mark_item_done("writing")
        return result.final_output_as(ReportData)

# %% [markdown]
# #### 🏗️ Activity #2:
#
# Convert the above flow into a flowchart style image (software of your choosing, but if you're not sure which to use try [Excallidraw](https://excalidraw.com/)) that outlines how the different Agents interact with each other.
#
# > HINT: Cursor's AI (CMD+L or CTRL+L on Windows) would be a helpful way to get a basic diagram that you can add more detail to!

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import FancyBboxPatch, ConnectionPatch
import numpy as np

# Set up the figure and axis
fig, ax = plt.subplots(1, 1, figsize=(14, 10))
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
ax.axis('off')

# Define colors
colors = {
    'user': '#E74C3C',      # Red
    'planner': '#3498DB',   # Blue
    'search': '#2ECC71',    # Green
    'writer': '#F39C12',    # Orange
    'output': '#9B59B6'     # Purple
}

# Define box positions with proper sequential flow
boxes = {
    'user_input': {
        'pos': (5, 8.5), 'size': (2, 0.8), 
        'text': 'User Query\nInput'
    },
    'planner_agent': {
        'pos': (5, 6.5), 'size': (2.5, 1.2), 
        'text': 'Planner Agent\n(GPT-4o)\n• Analyzes query\n• Generates search terms\n• Outputs WebSearchPlan'
    },
    'search_agent': {
        'pos': (5, 4.5), 'size': (2.5, 1.2), 
        'text': 'Search Agent\n(GPT-4o)\n• Uses WebSearchTool\n• Performs web searches\n• Summarizes results'
    },
    'writer_agent': {
        'pos': (5, 2.5), 'size': (2.5, 1.2), 
        'text': 'Writer Agent\n(o3-mini)\n• Synthesizes research\n• Creates report\n• Generates follow-ups'
    },
    'final_output': {
        'pos': (5, 0.8), 'size': (2.5, 0.8), 
        'text': 'Final Report\n(Markdown)'
    }
}

# Draw boxes
for name, box in boxes.items():
    x, y = box['pos']
    w, h = box['size']
    
    # Determine color based on box type
    if 'user' in name or 'input' in name:
        color = colors['user']
    elif 'planner' in name:
        color = colors['planner']
    elif 'search' in name:
        color = colors['search']
    elif 'writer' in name:
        color = colors['writer']
    else:
        color = colors['output']
    
    # Create rounded rectangle
    rect = FancyBboxPatch((x, y), w, h, 
                          boxstyle="round,pad=0.15",
                          facecolor=color, 
                          edgecolor='black',
                          linewidth=2.5,
                          alpha=0.9)
    ax.add_patch(rect)
    
    # Add text
    ax.text(x + w/2, y + h/2, box['text'], 
            ha='center', va='center', 
            fontsize=9, fontweight='bold',
            color='white' if name != 'user_input' else 'black',
            wrap=True)

# Define arrows with proper sequential flow
arrows = [
    # User to Planner
    ((6, 8.5), (6.25, 7.7), 'Query'),
    # Planner to Search
    ((6.25, 6.5), (6.25, 5.7), 'WebSearchPlan\n(Search Terms)'),
    # Search to Writer
    ((6.25, 4.5), (6.25, 3.7), 'Search Results\n(Summaries)'),
    # Writer to Final Output
    ((6.25, 2.5), (6.25, 1.6), 'Report Data\n(Report + Follow-ups)')
]

# Draw arrows
for start, end, label in arrows:
    arrow = ConnectionPatch(start, end, "data", "data",
                          arrowstyle="->", shrinkA=8, shrinkB=8,
                          mutation_scale=25, fc="black", lw=3)
    ax.add_patch(arrow)
    
    # Add label
    mid_x = (start[0] + end[0]) / 2
    mid_y = (start[1] + end[1]) / 2
    ax.text(mid_x, mid_y, label, ha='center', va='center',
            fontsize=8, fontweight='bold',
            bbox=dict(boxstyle="round,pad=0.3", 
                     facecolor='white', alpha=0.9,
                     edgecolor='black', linewidth=1))

# Add title
ax.text(5, 9.5, 'OpenAI Agents SDK Research Bot Flow', 
        ha='center', va='center', fontsize=16, fontweight='bold',
        bbox=dict(boxstyle="round,pad=0.5", facecolor='lightgray', alpha=0.8))

# Add legend
legend_elements = [
    patches.Patch(color=colors['user'], label='User Input'),
    patches.Patch(color=colors['planner'], label='Planning Agent'),
    patches.Patch(color=colors['search'], label='Search Agent'),
    patches.Patch(color=colors['writer'], label='Writing Agent'),
    patches.Patch(color=colors['output'], label='Output')
]

ax.legend(handles=legend_elements, loc='upper right', 
          bbox_to_anchor=(0.98, 0.98), fontsize=10)

# Add process flow description
description = """Correct Process Flow:
1. User provides research query
2. Planner Agent analyzes query and generates search terms
3. Search Agent uses search terms to perform web searches
4. Writer Agent synthesizes results into comprehensive report
5. Final output includes markdown report and follow-up questions

Key: Sequential flow, not parallel!"""

ax.text(8, 6, description, fontsize=10, 
        bbox=dict(boxstyle="round,pad=0.5", facecolor='lightblue', alpha=0.8),
        verticalalignment='top')

plt.tight_layout()
plt.savefig('agent_flowchart_correct.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ✅ Corrected flowchart saved as 'agent_flowchart_correct.png'
#
# Key corrections made:
# • Sequential flow: User → Planner → Search → Writer → Output
# • Proper data flow: Each agent passes output to the next
# • No parallel processing - Planner must complete before Search starts
# • Clear data labels showing what each agent passes to the next
# • Follow-up questions are part of final output, not separate loop

# %% [markdown]
# ## Task 5: Running Our Agent
#
# Now let's run our agent! The main function below will prompt the user for a research topic, then pass that query to our ResearchManager to handle the entire research process. The ResearchManager will:
#
# 1. Break down the query into search items
# 2. Search for information on each item
# 3. Write a comprehensive report based on the search results
#
# Let's see it in action!

# %%
async def main() -> None:
    query = input("What would you like to research? ")
    await ResearchManager().run(query)

# %%
asyncio.run(main())
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# =====REPORT=====
#
#
# Report: # Memorandum on Life Insurance Legal Topics
#
# ## I. Issue Statement
#
# This memorandum addresses a range of legal issues germane to life insurance policies, including but not limited to beneficiary rights arising from policy provisions, the contestability period and its implications, the legal and regulatory ramifications of material misrepresentations, fraud, and claims handling, as well as the impact of personal events such as divorce, suicide, and changes in marital status on beneficiary designations. Furthermore, the memorandum evaluates the responsibilities of insurers to act in good faith in claims adjudication, the statutory mechanisms governing unclaimed benefits, and the interplay between state and federal regulations that shape life insurance law in the United States.
#
# ## II. Brief Answer
#
# Life insurance law encompasses an array of legal principles that ensure policyholders’ and beneficiaries’ rights are protected while providing carriers with statutory guidelines for claim processing. Beneficiaries are entitled to notice and prompt payment of benefits, and policyholders must manage beneficiary designations consistent with both legislative requirements and contractual terms. Legal controversies commonly stem from misrepresentations, non-payment issues, improper alterations of beneficiary designations (especially under conditions of divorce or community property regimes), and fraud. Courts have consistently supported the requirement for disclosure and the doctrine of utmost good faith in insurance contracts, as exemplified in foundational cases such as Mutual Life Insurance Co. of New York v. Hillmon and Carter v. Boehm. Regulatory frameworks, often administered at the state level with guidelines from bodies like the NAIC, impose obligations on insurers to maintain transparency, fairness, and timely handling of claims. The memorandum recommends thorough review and proactive management of beneficiary designations and payment obligations, and it emphasizes the value of legal consultation in complex disputes.
#
# ## III. Facts
#
# 1. **Beneficiary Rights and Designations**
#    - Life insurance beneficiaries are legally entitled to be informed of their designation, to receive the full death benefit (including any accrued interest in case of delay), and to receive assistance when filing claims. ([life-insurance-lawyer.com](https://life-insurance-lawyer.com/life-insurance-beneficiary-rights/?utm_source=openai))
#    - Policyholders retain the authority to change revocable beneficiaries by executing a Change of Beneficiary form; however, any changes involving irrevocable beneficiaries require their consent. ([americanlifefund.com](https://www.americanlifefund.com/life-settlement/glossary/beneficiary/?utm_source=openai))
#    - In community property states such as California, special rules apply in which both spouses may have an interest in policies acquired during marriage, imposing additional consent requirements to modify beneficiary designations. ([gmlawyers.com](https://www.gmlawyers.com/california-life-insurance-beneficiary-laws/?utm_source=openai))
#
# 2. **Contestability and Misrepresentation**
#    - Insurers are allowed a contestability period, typically lasting two years from policy issuance, during which claims can be contested if material misrepresentations exist in the application. ([investopedia.com](https://www.investopedia.com/terms/i/incontestability-clause.asp?utm_source=openai))
#    - After the contestability period, policies become largely incontestable except in cases of outright fraud. ([usnews.com](https://www.usnews.com/insurance/life-insurance/what-is-a-incontestability-clause-in-life-insurance?utm_source=openai))
#    - Material misrepresentation (e.g., false statements regarding health or lifestyle) can lead to claim denials or rescission of policies, with varied standards among states such as New York and Florida. ([gmlawyers.com](https://www.gmlawyers.com/material-misrepresentation-in-life-insurance/?utm_source=openai))
#
# 3. **Claims Disputes and Insurance Fraud**
#    - Common disputes arise from alleged misrepresentations, policy lapses, or beneficiary disputes due to outdated designations, especially after divorce or remarriage. ([boonswanglaw.com](https://boonswanglaw.com/life-insurance-claim/life-insurance-beneficiary-rules-california/?utm_source=openai))
#    - Cases of life insurance fraud, including instances involving significant financial and criminal penalties, are treated severely at both state and federal levels. ([legalclarity.org](https://legalclarity.org/what-is-the-punishment-for-life-insurance-fraud/?utm_source=openai))
#
# 4. **Unclaimed Benefits and Probate Issues**
#    - Unclaimed benefits are addressed by state-level legislation modeled on the National Council of Insurance Legislators’ Act, requiring insurers to diligently notify beneficiaries and, if unlocated, escheat benefits to the state. ([policygenius.com](https://www.policygenius.com/life-insurance/unclaimed-life-insurance-act/?utm_source=openai))
#    - Life insurance proceeds normally bypass probate if a beneficiary designation is maintained, but may become part of the estate if no beneficiary is named or if the estate is the claimant. ([keyeslawgroup.com](https://keyeslawgroup.com/how-does-life-insurance-affect-probate/?utm_source=openai))
#
# 5. **Divorce and Beneficiary Changes**
#    - Divorce does not automatically revoke a beneficiary designation; therefore, it is incumbent upon policyholders to update their designations. Some jurisdictions have statutes automating the revocation upon divorce, as seen in Illinois and Minnesota (e.g., Sveen v. Melin). ([illinoislawforyou.com](https://illinoislawforyou.com/blog/navigating-life-insurance-divorce-settlements/?utm_source=openai))
#
# 6. **Suicide Clauses and Group Life Insurance**
#    - Life insurance policies typically include a suicide clause that excludes claims if suicide occurs within a specified period, commonly two years, although variations exist. ([law.cornell.edu](https://www.law.cornell.edu/wex/suicide_clause?utm_source=openai))
#    - Group life insurance, governed by federal laws like ERISA and state regulations, introduces additional factors regarding eligibility, benefits, and premium contributions. ([numberanalytics.com](https://www.numberanalytics.com/blog/navigating-group-life-insurance-law?utm_source=openai))
#
# ## IV. Discussion/Analysis
#
# ### A. Legal Obligations and Beneficiary Rights
#
# Life insurance law necessitates that both insurers and policyholders adhere to strict disclosure requirements and good faith dealings. Beneficiaries must be provided with full notice of their rights and the sum due, as failure to inform may result in legal challenges against insurers for breach of duty. The legal framework is designed to protect the reasonable expectations of beneficiaries as seen in **Mutual Life Insurance Co. of New York v. Hillmon (1892)**, where the Court recognized exceptions to customary evidentiary rules to honor the intentions of policyholders ([Wikipedia](https://en.wikipedia.org/wiki/Mutual_Life_Insurance_Co._of_New_York_v._Hillmon?utm_source=openai)).
#
# Furthermore, the doctrine of *uberrimae fidei* requires that policyholders disclose all material information. Failure to do so may trigger rescission of the policy or denial of the claim. The legal standards governing material misrepresentation vary significantly by jurisdiction. For instance, New York enforces a strict criterion: if the insurer would have declined the application upon knowing the accurate facts, the misrepresentation is deemed material ([dinnocenzolaw.com](https://www.dinnocenzolaw.com/practice-areas/insurance-denials/life-insurance-denials/material-misrepresentations-new-york/?utm_source=openai)).
#
# ### B. Contestability Period and Fraud
#
# The contestability period is central to the risk management of insurance companies. Statutorily, within the designated period—typically two years—insurers have the right to question the validity of the information provided on the application. This period serves to protect insurers from fraudulent claims, but also provides beneficiaries some assurance that minor inaccuracies will not lead to wrongful claim denials after the period elapses ([usnews.com](https://www.usnews.com/insurance/life-insurance/what-is-a-incontestability-clause-in-life-insurance?utm_source=openai)). Notably, even after the contestability period, intentional fraud remains grounds for claim denial, as seen in high-profile cases where fraudulent conduct resulted in severe legal penalties ([legalclarity.org](https://legalclarity.org/what-is-the-punishment-for-life-insurance-fraud/?utm_source=openai)).
#
# The regulatory landscape, with oversight at the state level supplemented by guidance from bodies like the NAIC, ensures that particularly egregious cases of fraud are met with both civil and criminal sanctions. This dual mechanism underscores the importance of maintaining truthful disclosures throughout the policy term.
#
# ### C. Claims Handling and Insurer Duties
#
# In handling claims, life insurance companies are obligated to observe the principles of fair dealing and exhibit good faith. This mandates clear communication with beneficiaries and prompt processing of claims. Failure to adhere to these standards may result in bad faith litigation and regulatory penalties. Courts have held insurers accountable when delays or lack of transparency result in unjust outcomes to beneficiaries, which further emphasizes the need for expedited and honest investigations into claims ([corporate.findlaw.com](https://corporate.findlaw.com/corporate-governance/obligations-of-insurance-companies-when-handling-claims.html/?utm_source=openai)).
#
# The legal principles governing insurer conduct are echoed by regulatory frameworks that impose duties such as maintaining comprehensive records, timely communication, and adherence to privacy laws. Additionally, statutory mandates compel insurers to undertake diligent efforts in locating beneficiaries, particularly in cases where benefits have become unclaimed. By cross-referencing state and federal records, insurers can ensure that property escheat provisions are properly administered when necessary ([policygenius.com](https://www.policygenius.com/life-insurance/unclaimed-life-insurance-act/?utm_source=openai)).
#
# ### D. Divorce, Community Property, and Beneficiary Updates
#
# The dynamics of divorce introduce complexities in beneficiary designations. Although many states do not automatically revoke an ex-spouse’s beneficiary status upon divorce, failure to update designations can result in unintended distributions. Courts have addressed this issue by upholding statutes and contractual provisions that attempt to automatically remove a former spouse—most notably in Sveen v. Melin ([en.wikipedia.org](https://en.wikipedia.org/wiki/Sveen_v._Melin?utm_source=openai)).
#
# In community property states such as California, where life insurance policies acquired during marriage are considered marital property, both spouses often have rights that significantly influence beneficiary designations. The policyholder must secure the consent of the other spouse before making modifications. This interplay between marital property rights and beneficiary designations underscores the necessity for individuals undergoing divorce to undertake a comprehensive review of their life insurance policies. Legal counsel should be engaged to ensure that any modifications are legally valid and reflective of the current intentions of the policyholder ([gmlawyers.com](https://www.gmlawyers.com/california-life-insurance-beneficiary-laws/?utm_source=openai)).
#
# ### E. Suicide Clause and Special Provisions
#
# Suicide clauses in life insurance policies serve as another critical area of legal complexity. Typically, these clauses exclude claim payouts if the insured dies by suicide within a predetermined exclusion period. While the standard period is two years in most states, variations exist that may shorten this period, as evidenced by the one-year exclusion in certain jurisdictions such as Colorado and North Dakota ([law.cornell.edu](https://www.law.cornell.edu/wex/suicide_clause?utm_source=openai)).
#
# This provision affects both the risk assessment process by insurers and the potential financial planning of policyholders and their beneficiaries. In scenarios where a policyholder’s intent is suspect or where mental health issues exist, insurers might scrutinize the circumstances of death closely within the contestability period. Conversely, group life policies or policies provided by the government (e.g., Servicemembers' Group Life Insurance) often carry alternative provisions regarding suicide that ensure benefits are paid regardless of the timing ([experian.com](https://www.experian.com/blogs/ask-experian/does-life-insurance-cover-suicidal-death/?utm_source=openai)).
#
# ### F. Regulatory and Jurisdictional Considerations
#
# Life insurance is predominantly regulated at the state level under the authority granted by the McCarran-Ferguson Act of 1945. This decentralized regulatory system allows each state to enact laws that address unique market conditions, consumer protections, and dispute mechanisms. Models provided by the NAIC and the Interstate Insurance Product Regulation Commission (IIPRC) help standardize policies and simplify cross-state operations for insurers ([findlaw.com](https://www.findlaw.com/consumer/insurance/insurance-regulation-overview.html/?utm_source=openai)).
#
# Despite the model regulations, significant variations exist in areas such as misrepresentation standards, beneficiary dispute resolutions, and the management of unclaimed benefits. Insurance practitioners must, therefore, maintain an awareness of both federal guidelines and state-specific nuances. By doing so, they can ensure compliance with applicable laws and effectively manage claims or litigation involving complex beneficiary or fraud-related issues.
#
# ### G. Landmark Case Law and Evolving Legal Precedents
#
# Precedent-setting cases significantly influence life insurance law. In addition to Mutual Life Insurance Co. of New York v. Hillmon and Carter v. Boehm, more recent jurisprudence, such as Equitable Life Assurance Society v. Hyman, emphasizes the principle that insurers must operate within the boundaries of contractual expectations and fair dealing ([Wikipedia](https://en.wikipedia.org/wiki/Equitable_Life_Assurance_Society_v_Hyman?utm_source=openai)).
#
# These cases collectively underscore several key points:
#
# 1. **Good Faith and Disclosure:** Both insurers and policyholders are held to high standards of disclosure and ethical conduct.
# 2. **Materiality of Information:** The materiality of presented information is a focal point in determining claim legitimacy and the enforceability of policies.
# 3. **State-Level Variance:** Jurisdiction-specific laws continue to modify how beneficiary designations, contestability, and misrepresentations are interpreted by the courts.
#
# The evolving landscape, as evidenced by Sveen v. Melin and other decisions, mandates a proactive approach to updating policy documents and beneficiary designations, particularly in light of lifestyle changes such as divorce or remarriage.
#
# ## V. Conclusion
#
# In conclusion, the legal framework governing life insurance policies is multifaceted and necessitates careful consideration of beneficiary rights, insurer obligations, and the statutory mechanisms that underpin the contestability and enforcement of policies. Beneficiary designations, while generally straightforward, become legally complex when complicated by factors such as divorce, community property rules, or allegations of fraud and misrepresentation. The contestability period remains a critical element for insurers, providing the necessary safeguards against misrepresentations, while simultaneously affirming the duty of good faith in handling claims.
#
# It is imperative for policyholders to regularly review and update beneficiary designations, and for insurers to rigorously adhere to statutory and regulatory requirements to minimize disputes and litigation risks. Legal practitioners should remain vigilant to ongoing judicial interpretations and regulatory updates that might impact these areas.
#
# The memorandum recommends that individuals engaged in life insurance planning or disputes consult with experienced legal counsel to ensure compliance with both state and federal requirements and to secure the intended benefits for policyholders and beneficiaries alike.
#
# **Citations:**
#
# - [Life Insurance Beneficiary Rights](https://life-insurance-lawyer.com/life-insurance-beneficiary-rights/?utm_source=openai)
# - [Change of Beneficiary Requirements](https://www.americanlifefund.com/life-settlement/glossary/beneficiary/?utm_source=openai)
# - [California Life Insurance Beneficiary Laws](https://www.gmlawyers.com/california-life-insurance-beneficiary-laws/?utm_source=openai)
# - [Contestability Clause Overview](https://www.investopedia.com/terms/i/incontestability-clause.asp?utm_source=openai)
# - [Mutual Life Insurance Co. v. Hillmon](https://en.wikipedia.org/wiki/Mutual_Life_Insurance_Co._of_New_York_v._Hillmon?utm_source=openai)
# - [Sveen v. Melin](https://en.wikipedia.org/wiki/Sveen_v._Melin?utm_source=openai)
#
# This memorandum serves as a comprehensive guide to the primary legal issues surrounding life insurance, offering insights into the prevailing legal doctrines and practical implications for clients involved either as policyholders or beneficiaries.
#
#
#
# =====FOLLOW UP QUESTIONS=====
#
#
# 1. What recent state-specific legislative changes have been enacted regarding the automatic revocation of ex-spouse beneficiary designations upon divorce?
# 2. How have courts across different jurisdictions interpreted the materiality standard in cases involving life insurance misrepresentations?
# 3. What impact have recent regulatory updates from the NAIC had on the enforcement of insurer duties regarding claims handling?
# 4. How do decisions in landmark cases like Equitable Life Assurance Society v. Hyman influence current contractual interpretations of life insurance policies?
# 5. What are the practical implications for policyholders regarding the renewal of the contestability period after a policy lapse or reinstatement?

# %% [markdown]
# ---
#
# ## Sample Report in Markdown
#
# ---

# %% [markdown]
# # OpenAI Agents SDK: A Comprehensive Report
#
# *Published: October 2023*
#
# ## Table of Contents
#
# 1. [Introduction](#introduction)
# 2. [Core Concepts and Key Features](#core-concepts-and-key-features)
# 3. [Architecture and Developer Experience](#architecture-and-developer-experience)
# 4. [Comparative Analysis with Alternative Frameworks](#comparative-analysis-with-alternative-frameworks)
# 5. [Integrations and Real-World Applications](#integrations-and-real-world-applications)
# 6. [Troubleshooting, Observability, and Debugging](#troubleshooting-observability-and-debugging)
# 7. [Community Impact and Future Directions](#community-impact-and-future-directions)
# 8. [Conclusion](#conclusion)
#
# ---
#
# ## Introduction
#
# In March 2025, OpenAI released the Agents SDK, a groundbreaking, open-source framework aimed at simplifying the development of autonomous AI agents capable of performing intricate tasks with minimal human intervention. Designed with a Python-first approach, the SDK offers a minimal set of abstractions, yet provides all the necessary components to build, debug, and optimize multi-agent workflows. The release marked a significant milestone for developers who seek to integrate large language models (LLMs) with advanced task delegation mechanisms, enabling next-generation automation in various industries.
#
# The primary goal of the OpenAI Agents SDK is to streamline the creation of agentic applications by offering core primitives such as *agents*, *handoffs*, and *guardrails*. These primitives are essential for orchestrating autonomous AI systems that perform key functions such as web search, file operations, and even actions on a computer. This report delves into the SDK's features, its operational architecture, integration capabilities, and how it compares to other frameworks in the rapidly evolving landscape of AI development tools.
#
# ## Core Concepts and Key Features
#
# ### Agents
#
# At the heart of the SDK are **agents**—intelligent entities that encapsulate a specific set of instructions and tools. Each agent is built on top of a large language model and can be customized with its own personality, domain expertise, and operational directives. For example, a "Math Tutor" agent could be designed to solve math problems by explaining each step clearly.
#
# **Key elements of an agent include:**
#
# - **Instructions:** Specific guidelines that shape the agent's responses and behavior in the context of its designated role.
# - **Tools:** Predefined or dynamically integrated tools that the agent can leverage to access external resources (e.g., web search or file search functionalities).
#
# ### Handoffs
#
# A unique feature introduced by the SDK is the concept of **handoffs**. Handoffs allow agents to delegate tasks to one another based on expertise and contextual needs. This orchestration paves the way for sophisticated workflows where multiple agents work in tandem, each contributing its specialized capabilities to complete a complex task.
#
# ### Guardrails
#
# Safety and reliability remain a cornerstone in AI development, and the SDK introduces **guardrails** as a means of controlling input and output validation. Guardrails help ensure that agents operate within defined safety parameters, preventing unintended actions and mitigating risks associated with autonomous decision-making.
#
# ### Built-in Debugging and Observability
#
# The development process is further enhanced by built-in **tracing and visualization tools**. These tools offer real-time insights into agent interactions, tool invocations, and decision-making pathways, thereby making debugging and optimization more accessible and systematic. The tracing functionality is a vital feature for developers looking to fine-tune agent performance in production environments.
#
# ## Architecture and Developer Experience
#
# ### Python-First Approach
#
# The SDK is inherently Python-based, making it highly accessible to the vast community of Python developers. By leveraging existing language features without introducing excessive abstractions, the SDK provides both simplicity and power. The installation is straightforward:
#
# ```bash
# mkdir my_project
# cd my_project
# python -m venv .venv
# source .venv/bin/activate
# pip install openai-agents
# ```
#
# Once installed, developers can create and configure agents with minimal boilerplate code. The emphasis on a minimal learning curve has been a significant point of praise among early adopters.
#
# ### Developer Tools and Tutorials
#
# In addition to comprehensive official documentation available on OpenAI’s GitHub pages, the community has contributed numerous tutorials and code examples. Video tutorials by experts such as Sam Witteveen and James Briggs provide hands-on demonstrations, ranging from simple agent creation to more sophisticated scenarios involving parallel execution and advanced tool integrations.
#
# ### Use of Python's Ecosystem
#
# The integration with Python’s ecosystem means that developers can immediately apply a range of established libraries and frameworks. For instance, utilizing Pydantic for input validation in guardrails or leveraging visualization libraries to display agent workflows are examples of how the SDK embraces the strengths of Python.
#
# ## Comparative Analysis with Alternative Frameworks
#
# While the OpenAI Agents SDK has received acclaim for its simplicity and robust integration with OpenAI’s ecosystem, other frameworks such as LangGraph, CrewAI, and AutoGen have emerged as viable alternatives. Here’s how they compare:
#
# - **LangGraph:** Known for its graph-based architecture, LangGraph is ideal for handling complex and cyclical workflows that require sophisticated state management. However, it comes with a steeper learning curve, making it less accessible for projects that require quick prototyping.
#
# - **CrewAI:** Emphasizing a role-based multi-agent system, CrewAI excels in scenarios where collaboration among agents is critical. Its design promotes clear segregation of duties among different agents, which can be beneficial in customer service or large-scale business automation.
#
# - **AutoGen:** This framework supports flexible conversation patterns and diverse agent interactions, particularly useful in applications where adaptive dialogue is essential. Nevertheless, AutoGen may introduce additional overhead when managing state and coordinating multiple agents.
#
# In contrast, the OpenAI Agents SDK strikes an effective balance by offering a lightweight yet powerful toolset geared towards production readiness. Its strengths lie in its minimal abstractions, ease of integration with various tools (like web search and file search), and built-in observability features that are crucial for debugging and tracing agent interactions.
#
# ## Integrations and Real-World Applications
#
# ### Diverse Integrations
#
# The real power of the OpenAI Agents SDK surfaces when it is integrated with other systems and platforms. Notable integrations include:
#
# - **Box Integration:** Enhancing enterprise content management, Box has adopted the SDK to enable secure AI-powered data processing. This integration allows agents to reliably access and interpret proprietary data.
#
# - **Coinbase AgentKit:** With financial capabilities in mind, Coinbase introduced AgentKit, leveraging the SDK to incorporate financial operations and risk analysis directly into AI agents.
#
# - **Milvus and Ollama:** These integrations allow the SDK to handle high-performance data queries and run agents on local infrastructure respectively, ensuring both speed and privacy.
#
# ### Real-World Applications
#
# The versatility of the SDK lends itself to a multitude of applications:
#
# - **Customer Support:** Automated agents can be built to handle customer inquiries, providing faster and more accurate responses while reducing workload on human agents.
#
# - **Content Generation:** In marketing and media, agents can generate high-quality articles, detailed reports, and even code reviews with built-in content guidelines.
#
# - **Financial Analysis:** Specialized agents capable of real-time data fetching and market analysis can generate actionable insights for investors and analysts.
#
# - **Health and Wellness:** Custom agents can handle tasks such as appointment scheduling, patient record management, and even provide personalized fitness and dietary recommendations.
#
# - **Educational Tools:** Intelligent tutoring agents can assist students by providing personalized learning experiences and instant feedback on assignments.
#
# These applications underscore the SDK’s transformative potential across various industries, driving the trend towards increased automation and efficiency.
#
# ## Troubleshooting, Observability, and Debugging
#
# ### Common Issues and Solutions
#
# As with any cutting-edge technology, developers working with the OpenAI Agents SDK have encountered challenges:
#
# - **API Key Management:** Authentication errors due to missing or invalid API keys are common. The solution involves ensuring that the `OPENAI_API_KEY` environment variable is correctly set or programmatically configured using OpenAI’s helper functions.
#
# - **Rate Limitations:** Rate limits, an intrinsic challenge with API-based services, require developers to monitor dashboard usage and implement retry strategies with exponential backoff.
#
# - **Response Delays:** Network latency and high server loads can result in unexpected delays. Developers are advised to check network settings, adhere to best practices in setting request timeouts, and monitor OpenAI’s service status.
#
# ### Built-In Tracing Capabilities
#
# The SDK provides robust tracing tools that log agent inputs, outputs, tool interactions, and error messages. This level of observability is crucial for debugging complex workflows and allows developers to visualize the agent’s decision-making process in real time. By configuring a `TracingConfig` object, developers can capture detailed insights and identify performance bottlenecks.
#
# ### Best Practices
#
# - **Prompt Engineering:** Refine prompts to reduce ambiguity and minimize unexpected outputs.
# - **Layered Validation:** Use guardrails extensively to ensure inputs and outputs are verified at multiple layers.
# - **Modular Design:** Break complex tasks into smaller, more manageable components using handoffs to delegate tasks appropriately.
#
# ## Community Impact and Future Directions
#
# ### Developer and Enterprise Adoption
#
# The release of the OpenAI Agents SDK has been met with enthusiasm within the developer community. Its ease of use, combined with comprehensive documentation and community-driven resources (such as tutorials on Class Central and DataCamp), has accelerated its adoption across educational, enterprise, and research sectors.
#
# Several leading organizations, including Box and Coinbase, have integrated the SDK into their workflows, demonstrating its capability to drive real-world business solutions. The open-source nature of the SDK, licensed under the MIT License, further encourages widespread industrial collaboration and innovation.
#
# ### Future Prospects
#
# Looking forward, OpenAI plans to extend the SDK’s support beyond Python, potentially embracing other programming languages like JavaScript. Additionally, future updates are anticipated to expand tool integrations, further enhance safety mechanisms, and streamline the development of multi-agent ecosystems. Planned deprecations of older APIs, such as the Assistants API in favor of the more unified Responses API, underline the SDK’s evolving roadmap aimed at future-proofing agentic applications.
#
# ## Conclusion
#
# The OpenAI Agents SDK represents a significant step forward in the field of AI development. Its lightweight, Python-first framework facilitates the creation of autonomous agents that can handle a wide array of tasks—from simple inquiries to complex multi-agent systems. The SDK’s robust integration capabilities, combined with its focus on safety and observability, make it an ideal choice for both developers and enterprises seeking to build reliable, scalable agentic applications.
#
# In summary, the SDK not only lowers the barrier to entry for developing sophisticated AI applications but also sets the stage for further innovations as the ecosystem evolves. It is poised to become a standard toolkit for the next generation of AI-driven technologies, empowering users across sectors to achieve greater efficiency and creativity in task automation.
#
# ---
#
# *For further reading, developers are encouraged to visit the official OpenAI documentation, join the community forums, and explore real-world use cases to deepen their understanding of this transformative tool.*
